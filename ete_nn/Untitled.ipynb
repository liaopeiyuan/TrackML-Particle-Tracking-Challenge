# %%
import numpy as np
import pandas as pd
import os

import keras
from keras.layers import Input, Dense, BatchNormalization, Dropout, PReLU
from keras.models import Model
from keras.models import load_model

from time import time

from keras.models import Model, load_model, Sequential
from keras.layers import Input, BatchNormalization, Add, Activation,Dense, PReLU, Dropout, Flatten,concatenate, Reshape
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D,AveragePooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from keras import backend as K
from keras.layers import Activation

# %%
from trackml.dataset import load_event

class Session(object):
    """
    A highly integrated framework for efficient data loading, prediction submission, etc. in TrackML Challenge
    (improved version of the official TrackML package)

    Precondition: the parent directory must be organized as follows:
    - train (directory)
        - event000001000-cells.csv
        ...
    - test (directory)
        - event000000001-cells.csv
        ...
    - detectors.csv
    - sample_submission.csv
    """
    # important constants to avoid spelling errors
    HITS = "hits"
    CELLS = "cells"
    PARTICLES = "particles"
    TRUTH = "truth"

    def __init__(self, parent_dir="./", train_dir="train/", test_dir="test/", detectors_dir="detectors.csv",
                 sample_submission_dir="sample_submission.csv"):
        """
        default input:
        Session("./", "train/", "test/", "detectors.csv", "sample_submission.csv")
        Session(parent_dir="./", train_dir="train/", test_dir="test/", detectors_dir="detectors.csv", sample_submission_dir="sample_submission.csv")
        """
        self._parent_dir = parent_dir
        self._train_dir = train_dir
        self._test_dir = test_dir
        self._detectors_dir = detectors_dir
        self._sample_submission_dir = sample_submission_dir

        if not os.path.isdir(self._parent_dir):
            raise ValueError("The input parent directory {} is invalid.".format(self._parent_dir))

        # there are 8850 events in the training dataset; some ids from 1000 to 9999 are skipped
        if os.path.isdir(self._parent_dir + self._train_dir):
            self._train_event_id_list = sorted(
                set(int(x[x.index("0"):x.index("-")]) for x in os.listdir(self._parent_dir + self._train_dir)))
        else:
            self._train_dir = None
            self._train_event_id_list = []

        if os.path.isdir(self._parent_dir + self._test_dir):
            self._test_event_id_list = sorted(
                set(int(x[x.index("0"):x.index("-")]) for x in os.listdir(self._parent_dir + self._test_dir)))
        else:
            self._test_dir = None
            self._test_event_id_list = []

        if not os.path.exists(self._parent_dir + self._detectors_dir):
            self._detectors_dir = None

        if not os.path.exists(self._parent_dir + self._sample_submission_dir):
            self._sample_submission_dir = None

    @staticmethod
    def get_event_name(event_id):
        return "event" + str(event_id).zfill(9)

    def get_train_events(self, n=10, content=(HITS, TRUTH), randomness=True):
        n = min(n, len(self._train_event_id_list))
        if randomness:
            event_ids = np.random.choice(self._train_event_id_list, size=n, replace=False).tolist()
        else:
            event_ids, = self._train_event_id_list[:n]
            self._train_event_id_list = self._train_event_id_list[n:] + self._train_event_id_list[:n]

        event_names = [Session.get_event_name(event_id) for event_id in event_ids]
        return event_names, \
            (load_event(self._parent_dir + self._train_dir + event_name, content) for event_name in event_names)

    def remove_train_events(self, n=10, content=(HITS, TRUTH), randomness=True):
        """
        get n events from self._train_event_id_list:
        if random, get n random events; otherwise, get the first n events
        :return:
         1. ids: event ids
         2. an iterator that loads a tuple of hits/cells/particles/truth files
        remove these train events from the current id list
        """
        n = min(n, len(self._train_event_id_list))
        if randomness:
            event_ids = np.random.choice(self._train_event_id_list, size=n, replace=False).tolist()
            for event_id in event_ids:
                self._train_event_id_list.remove(event_id)
        else:
            event_ids, self._train_event_id_list = self._train_event_id_list[:n], self._train_event_id_list[n:]

        event_names = [Session.get_event_name(event_id) for event_id in event_ids]
        return event_names, \
            (load_event(self._parent_dir + self._train_dir + event_name, content) for event_name in event_names)

    def get_test_event(self, n=3, content=(HITS, TRUTH), randomness=True):
        n = min(n, len(self._test_event_id_list))
        if randomness:
            event_ids = np.random.choice(self._test_event_id_list, size=n, replace=False).tolist()
        else:
            event_ids, = self._test_event_id_list[:n]
            self._test_event_id_list = self._test_event_id_list[n:] + self._test_event_id_list[:n]

        event_names = [Session.get_event_name(event_id) for event_id in event_ids]
        return event_names, \
            (load_event(self._parent_dir + self._test_dir + event_name, content) for event_name in event_names)
    
    def remove_test_events(self, n=10, content=(HITS, CELLS), randomness=False):
        n = min(n, len(self._test_event_id_list))
        if randomness:
            event_ids = np.random.choice(self._test_event_id_list, size=n, replace=False).tolist()
            for event_id in event_ids:
                self._test_event_id_list.remove(event_id)
        else:
            event_ids, self._test_event_id_list = self._test_event_id_list[:n], self._test_event_id_list[n:]
        event_names = [Session.get_event_name(event_id) for event_id in event_ids]
        return event_names, \
            (load_event(self._parent_dir + self._test_dir + event_name, content) for event_name in event_names)

    def make_submission(self, predictor, path):
        """
        :param predictor: function, predictor(hits: pd.DataFrame, cells: pd.DataFrame)->np.array
         takes in hits and cells data frames, return a numpy 1d array of cluster ids
        :param path: file path for submission file
        """
        sub_list = []  # list of predictions by event
        for event_id in self._test_event_id_list:
            event_name = Session.get_event_name(event_id)

            hits, cells = load_event(self._parent_dir + self._test_dir + event_name, (Session.HITS, Session.CELLS))
            pred = predictor(hits, cells)  # predicted cluster labels
            sub = pd.DataFrame({"hit_id": hits.hit_id, "track_id": pred})
            sub.insert(0, "event_id", event_id)
            sub_list.append(sub)
        final_submission = pd.concat(sub_list)
        final_submission.to_csv(path, sep=",", header=True, index=False)

# %%
def _get_quadratic_features(df):
    df["x2"] = df["x"] ** 2
    df["y2"] = df["y"] ** 2
    df["z2"] = df["z"] ** 2
    df["xy"] = df["x"] * df["y"]
    df["xz"] = df["x"] * df["z"]
    df["yz"] = df["y"] * df["z"]
    return df


def get_feature(hits, theta, flip, quadratic=True):
    """
    get the feature array for neural network fitting
    theta: the (radian) angle of rotation around the z axis
    flip: whether flip the points across the xy-plane
    """
    df = hits[["x", "y", "z"]].copy()
    r = np.sqrt(df["x"]**2 + df["y"]**2)
    a = np.arctan2(df["y"], df["x"]) + theta
    df.loc[:, "x"] = np.cos(a) * r
    df.loc[:, "y"] = np.sin(a) * r
    if flip:
        df.loc[:, "z"] = -df["z"]
    return (_get_quadratic_features(df) if quadratic else df).values


def get_target(hits):
    hits = hits[["particle_id"]].copy()
    hits = hits.merge(pd.DataFrame(hits.groupby("particle_id").size().rename("track_size")), left_on="particle_id", right_index=True)
    hits.loc[(hits["track_size"] < 4) | (hits["particle_id"] == 0), "particle_id"] = np.nan
    return pd.get_dummies(hits["particle_id"], dummy_na=False).values


def permute_target(target):
    return target[:, np.random.permutation(range(target.shape[1]))]


def join_hits_truth(hits, truth):
    hits = truth[["hit_id", "particle_id"]].merge(hits[["hit_id", "x", "y", "z"]], on="hit_id")
    hits.drop("hit_id", axis=1, inplace=True)
    return hits


def train_nn(nn_list, train_x, train_y, basic_trainable=True, epochs=10, batch_size=64, verbose=0):
    for layer in nn_list:
        layer.trainable = basic_trainable
    print(f"shape of fx: {train_x.shape}")
    print(f"shape of fy: {train_y.shape}")

    tensorboard = keras.callbacks.TensorBoard(log_dir='logs/')
    early_stopping = EarlyStopping(patience=50, verbose=1)
    model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1)
     
    n_targets = train_y.shape[1]
    output_layer = Dense(n_targets, activation="softmax", trainable=True)(nn_list[-1])
    if os.listdir("./checkpoint/") != []:
        print("Model present, loading model")
        temp_model = load_model("./checkpoint/mymodel.h5")
    else:
        print("Model not present, creating model")
        temp_model = Model(inputs=nn_list[0], outputs=output_layer)

    adam = keras.optimizers.adam(lr=0.001)
    temp_model.compile(optimizer=adam, loss="categorical_crossentropy")
    history = temp_model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=[tensorboard])

    losses = history.history['loss']
    return int(losses[len(losses)-1]), temp_model

# %%
def MLP_with_dropout(input_size=9, rate=0.5):
    nn_list = [Input(shape=(input_size,))]
    for layer in[
        Dense(32), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(64), BatchNormalization(), PReLU(),
        Dense(128), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(256), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(512), BatchNormalization(), PReLU(),
        Dense(1024), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(2048), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(4096), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(512), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(128), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(64), BatchNormalization(), PReLU(),
    ]:
      nn_list.append(layer(nn_list[-1]))
    return nn_list  

def MLP(input_size=9, rate=0.5):
    nn_list = [Input(shape=(input_size,))]
    for layer in[
        Dense(32, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        #Dropout(rate),
        Dense(64, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(128, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(128, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(128, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(128, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        #Dropout(rate),
        Dense(256, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(256, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(256, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(512, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(512, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(512, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(512, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dropout(rate),
        Dense(1024, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(1024, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
        Dense(1024, kernel_initializer='RandomUniform'), BatchNormalization(), PReLU(),
    ]:
      nn_list.append(layer(nn_list[-1]))
    return nn_list

# %%
print("start running basic neural network")
np.random.seed(1)  # restart random number generator
s1 = Session(parent_dir="/home/alexanderliao/data/Kaggle/competitions/trackml-particle-identification/")
n_events = 100
count = 0
nn_list_basic = MLP(9)

for hits_train, truth_train in s1.get_train_events(n=n_events, content=[s1.HITS, s1.TRUTH], randomness=True)[1]:
    count += 1
    print(f"{count}/{n_events}")
    hits_train = join_hits_truth(hits_train, truth_train)
    fy = get_target(hits_train)

    loss_global = 5000
    # fx = get_feature(hits, 0.0, flip=False, quadratic=True)
    for i in range(100):
        print("Step: " + str(i))
        loss, model = train_nn(nn_list_basic, get_feature(hits_train, theta=np.random.rand() * 2 * np.pi, flip=np.random.rand() < 0.5, quadratic=True), permute_target(fy),
        basic_trainable=True, epochs=20, batch_size=4096, verbose=1)
        if(loss<loss_global):
            print("Epoch result better than the best, saving model")
            model.save("./checkpoint/"+"mymodel.h5")
        # train_nn(nn_list_basic, fx, permute_target(fy), basic_trainable=True, epochs=4, batch_size=128, verbose=1)
# Out:
# start running basic neural network
# 1/100
# Step: 0
# shape of fx: (117544, 9)
# shape of fy: (117544, 8914)
# Model not present, creating model
# Epoch 1/20
# 117544/117544 [==============================] - 59s 506us/step - loss: 6.2233
# Epoch 2/20
# /home/alexanderliao/anaconda3/envs/py36/lib/python3.6/site-packages/keras/callbacks.py:432: RuntimeWarning: Can save best model only with val_loss available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 117544/117544 [==============================] - 56s 478us/step - loss: 3.6602
# Epoch 3/20
# 117544/117544 [==============================] - 56s 473us/step - loss: 2.9358
# Epoch 4/20
# 117544/117544 [==============================] - 58s 493us/step - loss: 2.5693
# Epoch 5/20
# 117544/117544 [==============================] - 56s 477us/step - loss: 2.3690
# Epoch 6/20
# 117544/117544 [==============================] - 57s 481us/step - loss: 2.2133
# Epoch 7/20
#  12288/117544 [==>...........................] - ETA: 48s - loss: 2.1217

# %%
os.listdir("/home/alexanderliao/data/Kaggle/competitions/trackml-particle-identification/"+"train/")
# Out:
# ['event000001357-truth.csv',
#  'event000001395-cells.csv',
#  'event000001027-cells.csv',
#  'event000001364-hits.csv',
#  'event000001554-cells.csv',
#  'event000001604-cells.csv',
#  'event000001826-truth.csv',
#  'event000001810-cells.csv',
#  'event000001742-truth.csv',
#  'event000001879-particles.csv',
#  'event000001326-truth.csv',
#  'event000001412-cells.csv',
#  'event000001206-cells.csv',
#  'event000001469-truth.csv',
#  'event000001462-particles.csv',
#  'event000001492-hits.csv',
#  'event000001855-particles.csv',
#  'event000001709-hits.csv',
#  'event000001610-particles.csv',
#  'event000001683-particles.csv',
#  'event000001217-truth.csv',
#  'event000001169-cells.csv',
#  'event000001553-truth.csv',
#  'event000001142-cells.csv',
#  'event000001139-hits.csv',
#  'event000001818-particles.csv',
#  'event000001856-hits.csv',
#  'event000001719-particles.csv',
#  'event000001443-particles.csv',
#  'event000001516-cells.csv',
#  'event000001071-hits.csv',
#  'event000001487-particles.csv',
#  'event000001065-hits.csv',
#  'event000001255-hits.csv',
#  'event000001541-hits.csv',
#  'event000001229-cells.csv',
#  'event000001532-particles.csv',
#  'event000001794-hits.csv',
#  'event000001718-truth.csv',
#  'event000001396-truth.csv',
#  'event000001161-cells.csv',
#  'event000001766-truth.csv',
#  'event000001871-particles.csv',
#  'event000001424-truth.csv',
#  'event000001236-hits.csv',
#  'event000001475-truth.csv',
#  'event000001353-particles.csv',
#  'event000001293-truth.csv',
#  'event000001606-cells.csv',
#  'event000001663-truth.csv',
#  'event000001344-hits.csv',
#  'event000001604-truth.csv',
#  'event000001670-truth.csv',
#  'event000001340-cells.csv',
#  'event000001141-hits.csv',
#  'event000001004-particles.csv',
#  'event000001326-hits.csv',
#  'event000001600-particles.csv',
#  'event000001658-truth.csv',
#  'event000001612-hits.csv',
#  'event000001504-hits.csv',
#  'event000001779-hits.csv',
#  'event000001799-truth.csv',
#  'event000001867-hits.csv',
#  'event000001356-cells.csv',
#  'event000001872-particles.csv',
#  'event000001876-particles.csv',
#  'event000001330-cells.csv',
#  'event000001589-particles.csv',
#  'event000001330-hits.csv',
#  'event000001648-cells.csv',
#  'event000001854-cells.csv',
#  'event000001705-hits.csv',
#  'event000001104-hits.csv',
#  'event000001645-particles.csv',
#  'event000001729-truth.csv',
#  'event000001461-particles.csv',
#  'event000001050-particles.csv',
#  'event000001864-truth.csv',
#  'event000001744-particles.csv',
#  'event000001266-hits.csv',
#  'event000001000-hits.csv',
#  'event000001442-particles.csv',
#  'event000001217-particles.csv',
#  'event000001128-cells.csv',
#  'event000001256-truth.csv',
#  'event000001275-hits.csv',
#  'event000001768-truth.csv',
#  'event000001727-cells.csv',
#  'event000001873-cells.csv',
#  'event000001468-particles.csv',
#  'event000001132-truth.csv',
#  'event000001846-truth.csv',
#  'event000001417-hits.csv',
#  'event000001847-cells.csv',
#  'event000001390-truth.csv',
#  'event000001546-cells.csv',
#  'event000001390-cells.csv',
#  'event000006403-particles.csv',
#  'event000001746-particles.csv',
#  'event000001186-particles.csv',
#  'event000001262-particles.csv',
#  'event000001756-truth.csv',
#  'event000001715-hits.csv',
#  'event000001489-hits.csv',
#  'event000001121-truth.csv',
#  'event000001838-cells.csv',
#  'event000001835-hits.csv',
#  'event000001017-cells.csv',
#  'event000001284-hits.csv',
#  'event000001308-particles.csv',
#  'event000001519-truth.csv',
#  'event000001813-truth.csv',
#  'event000001342-truth.csv',
#  'event000001501-truth.csv',
#  'event000001061-hits.csv',
#  'event000006407-particles.csv',
#  'event000001804-cells.csv',
#  'event000001605-particles.csv',
#  'event000001721-cells.csv',
#  'event000001653-particles.csv',
#  'event000001635-truth.csv',
#  'event000001186-cells.csv',
#  'event000001020-hits.csv',
#  'event000001815-particles.csv',
#  'event000001314-hits.csv',
#  'event000001213-hits.csv',
#  'event000001460-truth.csv',
#  'event000001495-hits.csv',
#  'event000001796-particles.csv',
#  'event000001460-particles.csv',
#  'event000001378-truth.csv',
#  'event000001043-particles.csv',
#  'event000001712-particles.csv',
#  'event000001315-cells.csv',
#  'event000001369-truth.csv',
#  'event000001158-truth.csv',
#  'event000001585-hits.csv',
#  'event000001889-cells.csv',
#  'event000001085-hits.csv',
#  'event000001161-hits.csv',
#  'event000001024-hits.csv',
#  'event000001341-hits.csv',
#  'event000001141-cells.csv',
#  'event000001337-particles.csv',
#  'event000001776-hits.csv',
#  'event000001308-hits.csv',
#  'event000001323-cells.csv',
#  'event000001535-hits.csv',
#  'event000001579-cells.csv',
#  'event000001526-particles.csv',
#  'event000001327-hits.csv',
#  'event000001025-particles.csv',
#  'event000001522-cells.csv',
#  'event000001100-truth.csv',
#  'event000001836-cells.csv',
#  'event000001409-cells.csv',
#  'event000001608-cells.csv',
#  'event000001009-particles.csv',
#  'event000001785-truth.csv',
#  'event000001605-truth.csv',
#  'event000001375-hits.csv',
#  'event000001749-hits.csv',
#  'event000001808-hits.csv',
#  'event000001347-particles.csv',
#  'event000001440-cells.csv',
#  'event000001467-hits.csv',
#  'event000001157-hits.csv',
#  'event000001676-cells.csv',
#  'event000001041-hits.csv',
#  'event000001076-cells.csv',
#  'event000001023-cells.csv',
#  'event000001867-cells.csv',
#  'event000001419-truth.csv',
#  'event000001713-particles.csv',
#  'event000001193-truth.csv',
#  'event000001184-particles.csv',
#  'event000001676-hits.csv',
#  'event000001342-cells.csv',
#  'event000001656-particles.csv',
#  'event000001741-particles.csv',
#  'event000001610-hits.csv',
#  'event000001602-truth.csv',
#  'event000001529-cells.csv',
#  'event000001168-cells.csv',
#  'event000001483-hits.csv',
#  'event000001818-cells.csv',
#  'event000001887-truth.csv',
#  'event000001170-particles.csv',
#  'event000001388-truth.csv',
#  'event000001840-particles.csv',
#  'event000001177-particles.csv',
#  'event000001090-particles.csv',
#  'event000001583-particles.csv',
#  'event000001025-cells.csv',
#  'event000001869-truth.csv',
#  'event000001466-cells.csv',
#  'event000001387-truth.csv',
#  'event000001071-cells.csv',
#  'event000001825-particles.csv',
#  'event000001104-truth.csv',
#  'event000001785-hits.csv',
#  'event000001526-hits.csv',
#  'event000001180-truth.csv',
#  'event000001809-hits.csv',
#  'event000006408-truth.csv',
#  'event000001395-particles.csv',
#  'event000001069-hits.csv',
#  'event000001450-cells.csv',
#  'event000001504-truth.csv',
#  'event000001543-truth.csv',
#  'event000001883-truth.csv',
#  'event000001257-particles.csv',
#  'event000001696-particles.csv',
#  'event000001107-hits.csv',
#  'event000001701-hits.csv',
#  'event000001038-cells.csv',
#  'event000001835-truth.csv',
#  'event000001469-cells.csv',
#  'event000001410-cells.csv',
#  'event000001101-hits.csv',
#  'event000001099-hits.csv',
#  'event000001265-particles.csv',
#  'event000001598-truth.csv',
#  'event000001670-cells.csv',
#  'event000001855-cells.csv',
#  'event000001277-particles.csv',
#  'event000001550-hits.csv',
#  'event000001298-cells.csv',
#  'event000001025-hits.csv',
#  'event000001321-hits.csv',
#  'event000001146-particles.csv',
#  'event000001856-particles.csv',
#  'event000001223-particles.csv',
#  'event000001336-cells.csv',
#  'event000001581-truth.csv',
#  'event000001780-hits.csv',
#  'event000001252-particles.csv',
#  'event000001669-hits.csv',
#  'event000001080-hits.csv',
#  'event000001032-cells.csv',
#  'event000001291-particles.csv',
#  'event000001085-truth.csv',
#  'event000001159-truth.csv',
#  'event000001535-particles.csv',
#  'event000001352-truth.csv',
#  'event000001146-truth.csv',
#  'event000001089-cells.csv',
#  'event000001074-truth.csv',
#  'event000001758-hits.csv',
#  'event000001223-hits.csv',
#  'event000001698-cells.csv',
#  'event000001221-truth.csv',
#  'event000001805-particles.csv',
#  'event000001377-hits.csv',
#  'event000001834-cells.csv',
#  'event000001420-hits.csv',
#  'event000001600-hits.csv',
#  'event000001308-cells.csv',
#  'event000001656-hits.csv',
#  'event000001553-cells.csv',
#  'event000001196-truth.csv',
#  'event000001271-particles.csv',
#  'event000001041-cells.csv',
#  'event000001361-particles.csv',
#  'event000001115-truth.csv',
#  'event000001509-cells.csv',
#  'event000001407-hits.csv',
#  'event000001817-truth.csv',
#  'event000001240-hits.csv',
#  'event000001753-truth.csv',
#  'event000001822-particles.csv',
#  'event000001052-truth.csv',
#  'event000001234-hits.csv',
#  'event000001732-particles.csv',
#  'event000001554-hits.csv',
#  'event000001732-cells.csv',
#  'event000001788-hits.csv',
#  'event000001595-truth.csv',
#  'event000001436-hits.csv',
#  'event000001403-particles.csv',
#  'event000001526-truth.csv',
#  'event000001394-hits.csv',
#  'event000001588-particles.csv',
#  'event000001351-cells.csv',
#  'event000001431-particles.csv',
#  'event000001704-particles.csv',
#  'event000001392-particles.csv',
#  'event000001061-particles.csv',
#  'event000001392-hits.csv',
#  'event000001333-particles.csv',
#  'event000001338-particles.csv',
#  'event000001595-hits.csv',
#  'event000001043-truth.csv',
#  'event000001288-cells.csv',
#  'event000001184-cells.csv',
#  'event000001892-cells.csv',
#  'event000001791-truth.csv',
#  'event000001851-cells.csv',
#  'event000001348-cells.csv',
#  'event000001417-truth.csv',
#  'event000001889-truth.csv',
#  'event000001135-truth.csv',
#  'event000001521-hits.csv',
#  'event000001028-hits.csv',
#  'event000001723-cells.csv',
#  'event000001057-particles.csv',
#  'event000001476-hits.csv',
#  'event000001853-truth.csv',
#  'event000006405-particles.csv',
#  'event000001805-hits.csv',
#  'event000001838-particles.csv',
#  'event000001621-hits.csv',
#  'event000001364-cells.csv',
#  'event000001628-hits.csv',
#  'event000001260-cells.csv',
#  'event000001852-cells.csv',
#  'event000001704-truth.csv',
#  'event000001882-truth.csv',
#  'event000001754-hits.csv',
#  'event000001175-particles.csv',
#  'event000006402-particles.csv',
#  'event000001342-particles.csv',
#  'event000001565-hits.csv',
#  'event000001635-hits.csv',
#  'event000001117-cells.csv',
#  'event000001832-particles.csv',
#  'event000001223-truth.csv',
#  'event000001888-hits.csv',
#  'event000001160-truth.csv',
#  'event000001008-truth.csv',
#  'event000001033-cells.csv',
#  'event000001417-particles.csv',
#  'event000001508-particles.csv',
#  'event000001040-hits.csv',
#  'event000001451-particles.csv',
#  'event000001062-hits.csv',
#  'event000001110-particles.csv',
#  'event000001454-hits.csv',
#  'event000001143-cells.csv',
#  'event000001830-cells.csv',
#  'event000001005-particles.csv',
#  'event000001855-hits.csv',
#  'event000001050-truth.csv',
#  'event000001350-truth.csv',
#  'event000001045-particles.csv',
#  'event000001659-truth.csv',
#  'event000001246-cells.csv',
#  'event000001180-cells.csv',
#  'event000001403-cells.csv',
#  'event000001890-hits.csv',
#  'event000001606-truth.csv',
#  'event000001858-particles.csv',
#  'event000001674-hits.csv',
#  'event000001307-cells.csv',
#  'event000001368-particles.csv',
#  'event000001447-cells.csv',
#  'event000001800-hits.csv',
#  'event000001268-particles.csv',
#  'event000001171-hits.csv',
#  'event000006404-hits.csv',
#  'event000001399-hits.csv',
#  'event000006404-cells.csv',
#  'event000001706-cells.csv',
#  'event000001658-particles.csv',
#  'event000001237-truth.csv',
#  'event000001559-particles.csv',
#  'event000001541-particles.csv',
#  'event000001665-cells.csv',
#  'event000001832-hits.csv',
#  'event000001234-particles.csv',
#  'untitled2.m',
#  'event000001058-hits.csv',
#  'event000001550-cells.csv',
#  'event000001188-particles.csv',
#  'event000001806-cells.csv',
#  'event000001302-truth.csv',
#  'event000001674-truth.csv',
#  'event000001177-truth.csv',
#  'event000001319-hits.csv',
#  'event000001654-cells.csv',
#  'event000001464-cells.csv',
#  'event000001421-hits.csv',
#  'event000001487-hits.csv',
#  'event000001472-hits.csv',
#  'event000001617-hits.csv',
#  'event000001157-particles.csv',
#  'event000001009-hits.csv',
#  'event000001748-particles.csv',
#  'event000001305-cells.csv',
#  'event000001059-hits.csv',
#  'event000001438-hits.csv',
#  'event000001624-hits.csv',
#  'event000001225-cells.csv',
#  'event000001110-cells.csv',
#  'event000001874-cells.csv',
#  'event000001174-particles.csv',
#  'event000001615-cells.csv',
#  'event000001628-cells.csv',
#  'event000001416-hits.csv',
#  'event000001465-cells.csv',
#  'event000001648-truth.csv',
#  'event000001243-particles.csv',
#  'event000001385-truth.csv',
#  'event000001830-truth.csv',
#  'event000001496-cells.csv',
#  'event000001104-cells.csv',
#  'event000001241-truth.csv',
#  'event000001567-cells.csv',
#  'event000001827-truth.csv',
#  'event000001511-cells.csv',
#  'event000001135-hits.csv',
#  'event000001264-hits.csv',
#  'event000001803-truth.csv',
#  'event000001672-particles.csv',
#  'event000001478-cells.csv',
#  'event000001816-particles.csv',
#  'event000001899-particles.csv',
#  'event000001746-cells.csv',
#  'event000001102-truth.csv',
#  'event000001007-hits.csv',
#  'event000001634-truth.csv',
#  'event000001089-truth.csv',
#  'event000001419-particles.csv',
#  'event000001402-truth.csv',
#  'event000006408-particles.csv',
#  'event000001229-particles.csv',
#  'event000001198-cells.csv',
#  'event000001202-cells.csv',
#  'event000001296-truth.csv',
#  'event000001551-truth.csv',
#  'event000001743-cells.csv',
#  'event000001200-hits.csv',
#  'event000001650-cells.csv',
#  'event000001207-particles.csv',
#  'event000001551-cells.csv',
#  'event000001692-cells.csv',
#  'event000001720-cells.csv',
#  'event000001150-hits.csv',
#  'event000001612-cells.csv',
#  'event000001880-truth.csv',
#  'event000001030-cells.csv',
#  'event000006409-particles.csv',
#  'event000001012-truth.csv',
#  'event000001386-hits.csv',
#  'event000001626-hits.csv',
#  'event000001037-truth.csv',
#  'event000001305-hits.csv',
#  'event000001828-cells.csv',
#  'event000001310-cells.csv',
#  'event000001100-particles.csv',
#  'event000001345-hits.csv',
#  'event000001574-truth.csv',
#  'event000001232-particles.csv',
#  'event000001162-particles.csv',
#  'event000001699-hits.csv',
#  'event000001107-cells.csv',
#  'event000001453-hits.csv',
#  'event000001872-cells.csv',
#  'event000001388-particles.csv',
#  'event000001483-particles.csv',
#  'event000001823-cells.csv',
#  'event000001545-truth.csv',
#  'event000001311-hits.csv',
#  'event000001153-cells.csv',
#  'event000001531-particles.csv',
#  'event000001798-truth.csv',
#  'event000001518-hits.csv',
#  'event000001063-cells.csv',
#  'event000001482-hits.csv',
#  'event000001529-hits.csv',
#  'event000001681-cells.csv',
#  'event000001540-hits.csv',
#  'event000001261-particles.csv',
#  'event000001616-truth.csv',
#  'event000001803-hits.csv',
#  'event000001520-truth.csv',
#  'event000001836-truth.csv',
#  'event000001510-hits.csv',
#  'event000001863-cells.csv',
#  'event000001292-hits.csv',
#  'event000001508-hits.csv',
#  'event000001316-cells.csv',
#  'event000001272-particles.csv',
#  'event000001726-hits.csv',
#  'event000001038-truth.csv',
#  'event000001288-hits.csv',
#  'event000001885-hits.csv',
#  'event000001200-truth.csv',
#  'event000001842-truth.csv',
#  'event000001876-truth.csv',
#  'event000001171-particles.csv',
#  'event000001322-truth.csv',
#  'event000001481-hits.csv',
#  'event000001667-truth.csv',
#  'event000001279-truth.csv',
#  'event000001642-cells.csv',
#  'event000001106-hits.csv',
#  'event000001531-hits.csv',
#  'event000001819-cells.csv',
#  'event000001177-hits.csv',
#  'event000001172-cells.csv',
#  'event000001810-hits.csv',
#  'event000001362-cells.csv',
#  'event000001495-truth.csv',
#  'event000001135-cells.csv',
#  'event000001003-cells.csv',
#  'event000001791-cells.csv',
#  'event000001138-hits.csv',
#  'event000001826-hits.csv',
#  'event000001293-hits.csv',
#  'event000001081-cells.csv',
#  'event000001706-particles.csv',
#  'event000001095-particles.csv',
#  'event000001889-hits.csv',
#  'event000001347-hits.csv',
#  'event000001717-hits.csv',
#  'event000001302-cells.csv',
#  'event000001004-hits.csv',
#  'event000001434-truth.csv',
#  'event000001295-cells.csv',
#  'event000001145-truth.csv',
#  'event000001620-truth.csv',
#  'event000001702-particles.csv',
#  'event000001750-cells.csv',
#  'event000001030-particles.csv',
#  'event000001694-particles.csv',
#  'event000001071-particles.csv',
#  'event000001857-particles.csv',
#  'event000001626-particles.csv',
#  'event000001422-truth.csv',
#  'event000001788-truth.csv',
#  'event000001195-particles.csv',
#  'event000001520-hits.csv',
#  'event000001109-particles.csv',
#  'event000001215-particles.csv',
#  'event000001590-particles.csv',
#  'event000001736-cells.csv',
#  'event000001144-truth.csv',
#  'event000001353-hits.csv',
#  'event000001635-particles.csv',
#  'event000001900-truth.csv',
#  'event000001661-cells.csv',
#  'event000001147-hits.csv',
#  'event000001377-truth.csv',
#  'event000001050-hits.csv',
#  'event000001046-particles.csv',
#  'event000001084-hits.csv',
#  'event000001372-hits.csv',
#  'event000001638-hits.csv',
#  'event000001002-cells.csv',
#  'event000001358-cells.csv',
#  'event000001743-hits.csv',
#  'event000001619-truth.csv',
#  'event000001244-particles.csv',
#  'event000001534-cells.csv',
#  'event000001091-cells.csv',
#  'event000001694-truth.csv',
#  'event000001498-hits.csv',
#  'event000001430-truth.csv',
#  'event000001443-truth.csv',
#  'event000001630-truth.csv',
#  'event000001095-truth.csv',
#  'event000001190-truth.csv',
#  'event000001149-hits.csv',
#  'event000001202-truth.csv',
#  'event000001253-cells.csv',
#  'event000001626-truth.csv',
#  'event000001520-particles.csv',
#  'event000001533-particles.csv',
#  'event000001064-truth.csv',
#  'event000001784-cells.csv',
#  'event000001305-particles.csv',
#  'event000001717-particles.csv',
#  'event000001662-cells.csv',
#  'event000001472-truth.csv',
#  'event000001297-hits.csv',
#  'event000001235-particles.csv',
#  'event000001623-particles.csv',
#  'event000001218-particles.csv',
#  'event000001413-particles.csv',
#  'event000001655-truth.csv',
#  'event000001014-cells.csv',
#  'event000001464-truth.csv',
#  'event000001062-particles.csv',
#  'event000001300-hits.csv',
#  'event000001850-hits.csv',
#  'event000001236-particles.csv',
#  'event000001277-truth.csv',
#  'event000001394-particles.csv',
#  'event000001775-particles.csv',
#  'event000001655-hits.csv',
#  'event000001023-hits.csv',
#  'event000001289-cells.csv',
#  'event000001599-particles.csv',
#  'event000001747-cells.csv',
#  'event000001599-truth.csv',
#  'event000001076-hits.csv',
#  'event000001507-cells.csv',
#  'event000001038-particles.csv',
#  'event000001039-particles.csv',
#  'event000001721-hits.csv',
#  'event000001104-particles.csv',
#  'event000001005-truth.csv',
#  'event000001688-truth.csv',
#  'event000001862-particles.csv',
#  'event000001452-particles.csv',
#  'event000001604-particles.csv',
#  'event000001808-cells.csv',
#  'event000001457-cells.csv',
#  'event000001210-particles.csv',
#  'event000001070-hits.csv',
#  'event000001611-cells.csv',
#  'event000001271-truth.csv',
#  'event000001781-hits.csv',
#  'event000001393-truth.csv',
#  'event000001130-cells.csv',
#  'event000001278-truth.csv',
#  'event000001813-hits.csv',
#  'event000001477-truth.csv',
#  'event000001756-cells.csv',
#  'event000001518-truth.csv',
#  'event000001547-hits.csv',
#  'event000001185-truth.csv',
#  'event000001711-particles.csv',
#  'event000001092-particles.csv',
#  'event000001269-truth.csv',
#  'event000001894-cells.csv',
#  'event000001439-cells.csv',
#  'event000001725-truth.csv',
#  'event000001780-truth.csv',
#  'event000001549-cells.csv',
#  'event000001329-particles.csv',
#  'event000001142-truth.csv',
#  'event000001379-hits.csv',
#  'event000001898-cells.csv',
#  'event000001161-particles.csv',
#  'event000001351-hits.csv',
#  'event000001814-hits.csv',
#  'event000001646-truth.csv',
#  'event000001859-particles.csv',
#  'event000001013-truth.csv',
#  'event000001714-truth.csv',
#  'event000001561-truth.csv',
#  'event000001745-particles.csv',
#  'event000001715-cells.csv',
#  'event000001126-truth.csv',
#  'event000001108-cells.csv',
#  'event000001253-hits.csv',
#  'event000001214-truth.csv',
#  'event000001208-hits.csv',
#  'event000001203-truth.csv',
#  'event000001733-cells.csv',
#  'event000001284-particles.csv',
#  'event000001708-hits.csv',
#  'event000001536-hits.csv',
#  'event000001772-hits.csv',
#  'event000001352-particles.csv',
#  'event000001047-cells.csv',
#  'event000001371-truth.csv',
#  'event000001800-particles.csv',
#  'event000001132-cells.csv',
#  'event000001075-hits.csv',
#  'event000001351-truth.csv',
#  'event000001661-truth.csv',
#  'event000001317-cells.csv',
#  'event000001563-truth.csv',
#  'event000001783-truth.csv',
#  'event000001499-cells.csv',
#  'event000001260-particles.csv',
#  'event000001137-hits.csv',
#  'event000001684-truth.csv',
#  'event000001082-truth.csv',
#  'event000001833-hits.csv',
#  'event000001700-cells.csv',
#  'event000001875-cells.csv',
#  'event000001895-hits.csv',
#  'event000001272-truth.csv',
#  'event000001324-hits.csv',
#  'event000001679-truth.csv',
#  'event000001644-truth.csv',
#  'event000001723-particles.csv',
#  'event000001545-particles.csv',
#  'event000001349-cells.csv',
#  'event000001211-cells.csv',
#  'event000001133-particles.csv',
#  'event000001897-truth.csv',
#  'event000001663-hits.csv',
#  'event000001580-cells.csv',
#  'event000001774-truth.csv',
#  'event000001013-particles.csv',
#  'event000001750-truth.csv',
#  'event000001651-hits.csv',
#  'event000001587-particles.csv',
#  'event000001812-cells.csv',
#  'event000001863-hits.csv',
#  'event000001316-hits.csv',
#  'event000001779-truth.csv',
#  'event000001809-particles.csv',
#  'event000001794-cells.csv',
#  'event000001809-truth.csv',
#  'event000001063-hits.csv',
#  'event000001728-truth.csv',
#  'event000001251-hits.csv',
#  'event000001817-cells.csv',
#  'event000001592-particles.csv',
#  'event000001558-cells.csv',
#  'event000001345-particles.csv',
#  'event000001678-hits.csv',
#  'event000001428-cells.csv',
#  'event000001248-particles.csv',
#  'event000001168-particles.csv',
#  'event000001185-particles.csv',
#  'event000001412-hits.csv',
#  'event000001379-particles.csv',
#  'event000001677-particles.csv',
#  'event000001884-hits.csv',
#  'event000001583-truth.csv',
#  'event000001872-truth.csv',
#  'event000001436-particles.csv',
#  'event000001833-cells.csv',
#  'event000001288-particles.csv',
#  'event000001579-hits.csv',
#  'event000001197-particles.csv',
#  'event000001010-particles.csv',
#  'event000001143-particles.csv',
#  'event000001495-particles.csv',
#  'event000001458-truth.csv',
#  'event000001054-hits.csv',
#  'event000001632-particles.csv',
#  'event000001348-hits.csv',
#  'event000001300-cells.csv',
#  'event000001884-cells.csv',
#  'event000001100-hits.csv',
#  'event000001791-hits.csv',
#  'event000001272-hits.csv',
#  'event000001587-hits.csv',
#  'event000001691-hits.csv',
#  'event000001502-particles.csv',
#  'event000001080-cells.csv',
#  'event000001254-hits.csv',
#  'event000001576-particles.csv',
#  'event000001538-hits.csv',
#  'net.mat',
#  'event000001473-hits.csv',
#  'event000001065-truth.csv',
#  'event000001331-particles.csv',
#  'event000001180-particles.csv',
#  'event000001893-hits.csv',
#  'event000001136-truth.csv',
#  'event000001461-hits.csv',
#  'event000001286-hits.csv',
#  'event000001384-cells.csv',
#  'event000001379-truth.csv',
#  'event000001165-particles.csv',
#  'event000001201-truth.csv',
#  'event000001067-hits.csv',
#  'event000001348-particles.csv',
#  'event000001404-particles.csv',
#  'event000001782-cells.csv',
#  'event000001464-hits.csv',
#  'event000001725-particles.csv',
#  'event000001714-cells.csv',
#  'event000001530-cells.csv',
#  'event000001891-truth.csv',
#  'event000001312-cells.csv',
#  'event000001569-truth.csv',
#  'event000001687-truth.csv',
#  'event000001260-hits.csv',
#  'event000001681-truth.csv',
#  'event000001449-truth.csv',
#  'event000001881-truth.csv',
#  'event000001892-truth.csv',
#  'event000001184-hits.csv',
#  'event000001887-particles.csv',
#  'event000001247-hits.csv',
#  'event000001245-cells.csv',
#  'event000001612-truth.csv',
#  'event000001019-truth.csv',
#  'event000001304-truth.csv',
#  'event000001812-particles.csv',
#  'event000001039-truth.csv',
#  'event000001154-truth.csv',
#  'event000001138-cells.csv',
#  'event000001370-cells.csv',
#  'event000001693-particles.csv',
#  'event000001371-particles.csv',
#  'event000001221-particles.csv',
#  'event000001028-particles.csv',
#  'event000001120-hits.csv',
#  'event000001801-hits.csv',
#  'event000001509-truth.csv',
#  'event000001614-truth.csv',
#  'event000001681-hits.csv',
#  'event000001517-truth.csv',
#  'event000001230-cells.csv',
#  'event000001704-hits.csv',
#  'event000001656-cells.csv',
#  'event000001784-particles.csv',
#  'event000001616-hits.csv',
#  'event000001841-cells.csv',
#  'event000001389-hits.csv',
#  'event000001785-particles.csv',
#  'event000001569-particles.csv',
#  'event000001546-particles.csv',
#  'event000001303-hits.csv',
#  'event000001210-cells.csv',
#  'event000001087-particles.csv',
#  'event000001111-cells.csv',
#  'event000001684-cells.csv',
#  'event000001373-hits.csv',
#  'event000001322-cells.csv',
#  'event000001600-cells.csv',
#  'event000001370-hits.csv',
#  'event000001322-hits.csv',
#  'event000001249-particles.csv',
#  'event000001319-particles.csv',
#  'event000001290-truth.csv',
#  'event000001556-truth.csv',
#  'event000001518-particles.csv',
#  'event000001560-hits.csv',
#  'event000001559-cells.csv',
#  'event000001207-hits.csv',
#  'event000001650-particles.csv',
#  'event000001510-particles.csv',
#  'event000001205-particles.csv',
#  'event000001694-hits.csv',
#  'event000001248-hits.csv',
#  'event000001684-particles.csv',
#  'event000001031-particles.csv',
#  'event000001081-hits.csv',
#  'event000001774-cells.csv',
#  'event000001853-particles.csv',
#  'event000001156-hits.csv',
#  'event000001348-truth.csv',
#  'event000001710-truth.csv',
#  'event000001047-hits.csv',
#  'event000001758-cells.csv',
#  'event000001183-hits.csv',
#  'event000001194-hits.csv',
#  'train.csv',
#  'event000001364-particles.csv',
#  'event000001031-truth.csv',
#  'event000001136-particles.csv',
#  'event000001737-cells.csv',
#  'event000001579-truth.csv',
#  'event000001510-truth.csv',
#  'event000001502-hits.csv',
#  'event000001373-cells.csv',
#  'event000001516-truth.csv',
#  'event000001054-particles.csv',
#  'event000001696-hits.csv',
#  'event000001192-cells.csv',
#  'event000001059-particles.csv',
#  'event000001593-truth.csv',
#  'event000001523-truth.csv',
#  'event000001017-truth.csv',
#  'event000001544-cells.csv',
#  'event000001254-cells.csv',
#  'event000001235-hits.csv',
#  'event000001293-particles.csv',
#  'event000001099-truth.csv',
#  'event000001362-particles.csv',
#  'event000001423-particles.csv',
#  'event000001106-particles.csv',
#  'event000001043-hits.csv',
#  'event000001197-cells.csv',
#  'event000001654-hits.csv',
#  'event000001239-cells.csv',
#  'event000001386-particles.csv',
#  'event000001844-particles.csv',
#  'event000001492-cells.csv',
#  'event000001462-cells.csv',
#  'event000001614-hits.csv',
#  'event000001446-cells.csv',
#  'event000001572-truth.csv',
#  'event000001299-hits.csv',
#  'event000001661-hits.csv',
#  'event000001268-truth.csv',
#  'event000001432-truth.csv',
#  'event000001596-cells.csv',
#  'event000001843-particles.csv',
#  'event000001700-truth.csv',
#  'event000001623-truth.csv',
#  'event000001191-hits.csv',
#  'event000001786-cells.csv',
#  'event000001083-cells.csv',
#  'event000001222-cells.csv',
#  'event000001497-cells.csv',
#  'event000001166-cells.csv',
#  'event000001324-truth.csv',
#  'event000001709-truth.csv',
#  'event000001807-particles.csv',
#  'event000001511-particles.csv',
#  'event000001797-particles.csv',
#  'event000001313-hits.csv',
#  'event000001535-truth.csv',
#  'event000001608-particles.csv',
#  'event000001130-hits.csv',
#  'event000001351-particles.csv',
#  'event000001388-hits.csv',
#  'event000001457-hits.csv',
#  'event000001625-truth.csv',
#  'event000001624-particles.csv',
#  'event000001485-truth.csv',
#  'event000001085-particles.csv',
#  'event000001092-truth.csv',
#  'event000001548-hits.csv',
#  'event000001732-hits.csv',
#  'event000001166-particles.csv',
#  'event000001773-truth.csv',
#  'event000001097-cells.csv',
#  'event000001337-cells.csv',
#  'event000001843-cells.csv',
#  'event000001749-cells.csv',
#  'event000001299-cells.csv',
#  'event000001702-truth.csv',
#  'event000001283-particles.csv',
#  'event000001797-hits.csv',
#  'event000001792-cells.csv',
#  'event000001631-hits.csv',
#  'event000001868-cells.csv',
#  'event000001189-hits.csv',
#  'event000001008-hits.csv',
#  'event000001549-particles.csv',
#  'event000001699-particles.csv',
#  'event000001273-truth.csv',
#  'event000001565-truth.csv',
#  'event000001580-particles.csv',
#  'event000001293-cells.csv',
#  'event000001817-particles.csv',
#  'event000001286-truth.csv',
#  'event000001022-truth.csv',
#  'event000001838-hits.csv',
#  'event000001781-cells.csv',
#  'event000001833-particles.csv',
#  'event000001710-particles.csv',
#  'event000001184-truth.csv',
#  'event000001283-cells.csv',
#  'event000001175-truth.csv',
#  'event000001642-truth.csv',
#  'event000001505-cells.csv',
#  'event000001493-hits.csv',
#  'event000001229-truth.csv',
#  'event000001618-cells.csv',
#  'event000001241-particles.csv',
#  'event000001690-cells.csv',
#  'event000001659-hits.csv',
#  'event000001307-hits.csv',
#  'event000001636-truth.csv',
#  'event000001343-particles.csv',
#  'event000001475-particles.csv',
#  'event000001778-truth.csv',
#  'event000001876-cells.csv',
#  'event000001899-cells.csv',
#  'event000001661-particles.csv',
#  'event000001018-hits.csv',
#  'event000001158-particles.csv',
#  'event000001005-cells.csv',
#  'event000001719-hits.csv',
#  'event000001446-hits.csv',
#  'event000001645-truth.csv',
#  'event000001416-truth.csv',
#  'event000001336-particles.csv',
#  'event000001437-truth.csv',
#  'event000001403-hits.csv',
#  'event000001761-particles.csv',
#  'event000001089-particles.csv',
#  'event000001374-cells.csv',
#  'event000001107-truth.csv',
#  'event000001625-cells.csv',
#  'event000001376-truth.csv',
#  'event000001303-particles.csv',
#  'event000001514-truth.csv',
#  'event000001366-particles.csv',
#  'event000001022-particles.csv',
#  'event000001480-hits.csv',
#  'event000001529-particles.csv',
#  'event000001207-cells.csv',
#  'event000001283-hits.csv',
#  'event000001872-hits.csv',
#  'event000001020-truth.csv',
#  'event000001650-hits.csv',
#  'event000001006-particles.csv',
#  'event000001105-hits.csv',
#  'event000001557-hits.csv',
#  'event000001556-particles.csv',
#  'event000001665-particles.csv',
#  'event000001022-cells.csv',
#  'event000001894-particles.csv',
#  'event000001121-particles.csv',
#  'event000001188-hits.csv',
#  'event000001570-particles.csv',
#  'event000001556-cells.csv',
#  'event000001238-hits.csv',
#  'event000001501-cells.csv',
#  'event000001158-cells.csv',
#  'event000001204-truth.csv',
#  'event000001082-hits.csv',
#  'event000001000-cells.csv',
#  ...]
